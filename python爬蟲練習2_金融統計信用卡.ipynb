# %% [markdown]
# ## 金融統計輯要- 信用卡篇
#
# #### 目標網站:[信用卡業務資訊揭露](http://www.banking.gov.tw/ch/home.jsp?id=192&parentpath=0,4&mcustomize=multimessage_view.jsp&dataserno=21207&aplistdn=ou=disclosure,ou=multisite,ou=chinese,ou=ap_root,o=fsc,c=tw&dtable=Disclosure)
#
# #### 說明:
# 本練習為利用程式自動下載檔案，解壓縮後的excel檔經過簡單的ETL後存入資料庫。
#
# #### 預期目標:
#
# 1. 找到目標網站,例如:105年9月下載連結[在此](http://www.fsc.gov.tw/fckdowndoc?file=/10509_信用卡重要資訊揭露.zip&flag=doc)
# 2. 解壓縮檔案(.zip)
# 3. ETL
# 4. 存進資料庫
# 5. 封裝以上流程

# %% [markdown]
# #### 下載檔案
#
# 連結指向.zip檔案，只要使用`request`就能取得內容。先讓檔案存在本地端，再做後續處理。

# %%
import requests # 
url_download = 'http://www.fsc.gov.tw/fckdowndoc?file=/10509_信用卡重要資訊揭露.zip&flag=doc'
res = requests.get(url_download)

# %%
zip_filename = './data/credit_card_' + str(10509) + '.zip' 

with open(zip_filename,'wb') as handle:
    if not res.ok:
        print 'OOPS, something wrong!'
    else:
        for block in res.iter_content(1024):
            handle.write(block)

# %% [markdown]
# #### 解壓縮

# %%
zip_dir = './data/credit_card_' + str(10509)

# %%
import zipfile

zip_ref = zipfile.ZipFile(zip_filename, 'r')
zip_ref.extractall(zip_dir)
zip_ref.close()

# %% [markdown]
# #### 處理下載的`.xlsx`檔案

# %%
import pandas as pd

# %%
xlsx_path = zip_dir +'/'+ str(10509) + u'_信用卡重要資訊揭露.xlsx'
df = pd.read_excel(xlsx_path)
df
# Out:
#                                    信用卡重要業務及財務資訊(資訊揭露) Unnamed: 1 Unnamed: 2  \
# 0                                                 NaN        NaN        NaN
# 1                                                 NaN        NaN        NaN
# 2                                       金額單位：新臺幣千元 ,卡        NaN        NaN
# 3                                              金融機構名稱       流通卡數       有效卡數
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN        NaN        NaN
# 7
# 8                                                臺灣銀行     229685     108569
# 9                                              臺灣土地銀行     226874     123797
# 10                                           合作金庫商業銀行     434661     264265
# 11                                             第一商業銀行     944592     632028
# 12                                             華南商業銀行     860317     624604
# 13                                             彰化商業銀行     433112     210300
# 14                                           上海商業儲蓄銀行     355758     177470
# 15                                           台北富邦商業銀行    2381409    1699013
# 16                                           國泰世華商業銀行    5819486    3987545
# 17                                               高雄銀行       9995       4621
# 18                                           兆豐國際商業銀行     605157     410685
# 19                                         花旗(台灣)商業銀行    2897079    2451755
# 20                                         澳盛(台灣)商業銀行     551116     337897
# 21                                           臺灣中小企業銀行     331621     126622
# 22                                           渣打國際商業銀行     356338     215141
# 23                                             台中商業銀行     198983      78440
# 24                                         匯豐(台灣)商業銀行     603903     416222
# 25                                             華泰商業銀行      10182       6286
# 26                                           臺灣新光商業銀行     906911     480883
# 27                                             陽信商業銀行      87424      50234
# 28                                             三信商業銀行      17140      11172
# 29                                             聯邦商業銀行    1995367    1014822
# 30                                           遠東國際商業銀行    1512147    1016613
# 31                                             元大商業銀行     547435     342086
# 32                                             永豐商業銀行    1952814    1340289
# 33                                             玉山商業銀行    4220605    2936664
# 34                                             凱基商業銀行     507286     198035
# 35                                         星展(台灣)商業銀行      12823       5910
# 36                                           台新國際商業銀行    3624881    2542358
# 37                                             大眾商業銀行     597887     324881
# 38                                           日盛國際商業銀行     178704     100513
# 39                                             安泰商業銀行     181749      70301
# 40                                           中國信託商業銀行    5928093    3838080
# 41                                       台灣樂天信用卡(股)公司     170451     129353
# 42                                      台灣美國運通國際(股)公司     168562     112880
# 43                                       台灣永旺信用卡(股)公司      86657      36274
# 44                                                 總計   39947204   26426608
# 45                                  一、資料來源：各金融機構自行申報。        NaN        NaN
# 46                                       二、揭露項目及認定標準：        NaN        NaN
# 47                       　1.流通卡數：發卡總數減停卡總數，且卡片狀況為正常者。        NaN        NaN
# 48  　2.有效卡數：最近六個月有消費紀錄之卡，不含Debit卡，只有郵購分期交易亦算有效卡，不含...        NaN        NaN
# 49                                 　3.當月發卡數：不含補發卡、續卡。        NaN        NaN
# 50                                  　4.當月停卡數：指新增停卡部分。        NaN        NaN
# 51                          　5.循環信用餘額：係指持卡人使用循環信用之餘額。        NaN        NaN
# 52                 　6.未到期分期付款餘額：包括預借現金分期、消費帳款分期及帳單分期。        NaN        NaN
# 53      　7.當月簽帳金額：係指持卡人當月刷卡消費金額，如屬分期消費帳款應於消費當月全數申報本欄。        NaN        NaN
# 54  　8.當月預借現金金額：係指持卡人當月動用預借現金金額，如屬分期預借現金應於動用當月全數申報本欄。        NaN        NaN
# 55  　9.逾期帳款：指持卡人每月繳款金額未達最低應繳金額、及雖未超逾期限但已向主、從債務人訴追者...        NaN        NaN
# 56  　　　　　　　款。若持卡人已逾期達數月，而嗣後繳付金額僅涵蓋一個月的最低應繳金額，則逾期期間...        NaN        NaN
# 57          　　　　　　　月，須俟持卡人將所積欠各期最低應繳金額全部償還後，始得回復為未逾期。        NaN        NaN
# 58                    　10.備抵呆帳提足率：實際提列備抵呆帳占應提備抵呆帳之比率。        NaN        NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5      Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0         NaN        NaN        NaN             NaN        NaN        NaN
# 1         NaN        NaN        NaN             NaN        NaN        NaN
# 2         NaN        NaN        NaN  資料月份：105 年 9 月        NaN        NaN
# 3       當月發卡數      當月停卡數       循環信用             未到期       當月簽帳       當月預借
# 4           　          　         餘額            分期付款         金額       現金金額
# 5           　          　          　              餘額
# 6         NaN        NaN        NaN             NaN        NaN        NaN
# 7
# 8        1403        773     227510            8564     591923       1125
# 9        3130        750     273104           49967     802498        842
# 10       4428       3048     632591          204449    2298644       3452
# 11       9874       8862    1422132         1010711    3768957      14321
# 12      11612       7488     746874         1722842    3471889        996
# 13       2596       3545     368688          163663    1202909        490
# 14       1428       1781     736921          183239    1046060       7095
# 15     105020      26099    6311070         8321286   15414178      44722
# 16     167547      30382   14403009        10716675   28436766     226868
# 17        119         40       7595             112     161677        181
# 18       6858      17932    1156534          751060    2332768       5486
# 19      20560      28657   15625833         9428296   19323772     190571
# 20       3845      12350    3022184         1563877    2821580      20955
# 21        646       1121     459121           81551     820864       4100
# 22        998       3719    1889387          579747    1341776       9266
# 23       1794       1090     269003           43756     474355          0
# 24       5832       9966    2680380         1542599    3807238      50395
# 25          7         12      19948            2825      50429          0
# 26       7411       9600    2067667         1268711    3638242      12493
# 27       1395        647     243844           61201     265218        148
# 28        108         58      31725           13959     115185         55
# 29      43706      28514    4724627         2711166    6477824      93471
# 30      39453       7455    4746159         5808441    4172060     189430
# 31      11305       2894     531881          481069    3954299        804
# 32      14308      15191    4909879         3932349    6183786     113347
# 33      38711      23829   11232451        10438148   24361710     178144
# 34       7647       9681    1109222          338650    1012383       8883
# 35         41         56      21865             141      52031         11
# 36      29640      21922   10181705        12781989   16366281     155959
# 37       7595       5335     932445         3609817    1773563      69547
# 38        368       2626     449772          215409     375303       5259
# 39        756        343     382727         1277871     449745       1046
# 40      56544      37699   14633924        14504022   25263572     645018
# 41      10113        411     117355          173012     657598       1468
# 42       3632       2464     339365               0    4064483       2294
# 43         79        562     267076           46918     150126       2413
# 44     620509     326902  107175573        94038092  187501692    2060655
# 45        NaN        NaN        NaN             NaN        NaN        NaN
# 46        NaN        NaN        NaN             NaN        NaN        NaN
# 47        NaN        NaN        NaN             NaN        NaN        NaN
# 48        NaN        NaN        NaN             NaN        NaN        NaN
# 49        NaN        NaN        NaN             NaN        NaN        NaN
# 50        NaN        NaN        NaN             NaN        NaN        NaN
# 51        NaN        NaN        NaN             NaN        NaN        NaN
# 52        NaN        NaN        NaN             NaN        NaN        NaN
# 53        NaN        NaN        NaN             NaN        NaN        NaN
# 54        NaN        NaN        NaN             NaN        NaN        NaN
# 55        NaN        NaN        NaN             NaN        NaN        NaN
# 56        NaN        NaN        NaN             NaN        NaN        NaN
# 57        NaN        NaN        NaN             NaN        NaN        NaN
# 58        NaN        NaN        NaN             NaN        NaN        NaN
#
#    Unnamed: 9  Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0         NaN          NaN         NaN         NaN         NaN
# 1         NaN          NaN         NaN         NaN         NaN
# 2         NaN          NaN         NaN         NaN         NaN
# 3       逾期三個月        逾期六個月        備抵呆帳        當月轉銷       當年度轉銷
# 4       以上帳款占        以上帳款占         提足率        呆帳金額        呆帳金額
# 5       應收帳款餘        應收帳款餘         (%)           　         累計至
# 6     額(含催收款)      額(含催收款)         NaN         NaN        資料月份
# 7      之比率(%)       之比率(%)                                 NaN
# 8    0.361745     0.136023     500.685         501        7515
# 9    0.349979     0.198352      1327.9        2632       13232
# 10   0.297598     0.216379     335.775        6157       34336
# 11   0.169761            0     1874.76        5490       50783
# 12  0.0669013            0     769.897       11522       36400
# 13   0.345814   0.00649045     666.759        2636       20324
# 14    0.87219     0.352317     1771.86           0       21170
# 15   0.163105  0.000277302     744.728       24720      212163
# 16   0.128559            0     2434.67       31589      274472
# 17   0.219022     0.113632     285.957          52         915
# 18   0.183019     0.048749     628.492        2295       33322
# 19   0.488565    0.0941192     652.889       57423      594087
# 20   0.378906            0     424.536       10956      122404
# 21   0.128454   0.00210456     147.257        2371       20444
# 22   0.396444            0     552.697        9909      102963
# 23    2.02698     0.748579     248.822           0       16482
# 24   0.260166            0      2557.1        6834       67535
# 25   0.361392            0     243.439        1470        1758
# 26   0.236032    0.0143305     237.573        6889       51659
# 27  0.0142608            0     1246.37        3546       10716
# 28   0.508859            0     5068.36         341        1761
# 29   0.286149            0     120.432       15815      126547
# 30   0.398506     0.125672     100.287       15940      142181
# 31   0.133333            0      1149.5        1886       15677
# 32   0.325352            0     602.788       16569      136182
# 33   0.243551            0     1119.39       37844      343137
# 34    1.16898     0.639434     146.299        7803       61786
# 35    2.45433            0     517.667         313        1616
# 36   0.229598   0.00277346     611.496       22035      204343
# 37  0.0179927      0.01662     476.395       13202       89099
# 38   0.281333            0     245.367        1703       12195
# 39   0.546158     0.129156     293.397           0       10462
# 40   0.163211  0.000420497     616.153       63781      544921
# 41   0.158867   0.00846625     292.278         438        1510
# 42   0.252435            0     280.573        2508       20645
# 43   0.799284      0.15881     2229.39        1631       17893
# 44   0.253859    0.0257416     605.656      388801     3422635
# 45        NaN          NaN         NaN         NaN         NaN
# 46        NaN          NaN         NaN         NaN         NaN
# 47        NaN          NaN         NaN         NaN         NaN
# 48        NaN          NaN         NaN         NaN         NaN
# 49        NaN          NaN         NaN         NaN         NaN
# 50        NaN          NaN         NaN         NaN         NaN
# 51        NaN          NaN         NaN         NaN         NaN
# 52        NaN          NaN         NaN         NaN         NaN
# 53        NaN          NaN         NaN         NaN         NaN
# 54        NaN          NaN         NaN         NaN         NaN
# 55        NaN          NaN         NaN         NaN         NaN
# 56        NaN          NaN         NaN         NaN         NaN
# 57        NaN          NaN         NaN         NaN         NaN
# 58        NaN          NaN         NaN         NaN         NaN

# %% [markdown]
# #### 清理資料
# * 觀察需要擷取的資料位在第8-44行
# * 重新命名欄位
# * 定義欄位資料型態(dtype)

# %%
df_temp = df[8:44];
col_names = [u'金融機構名稱',u'流通卡數',u'有效卡數',u'當月發卡數',u'當月停卡數',u'循環信用餘額(仟)',
             u'未到期分期付款餘額(仟)',u'當月簽帳金額(仟)',u'當月預借現金金額(仟)',
             u'逾期三個月以上比率(%)',
             u'逾期六個月以上比率(%)',
             u'備抵呆帳提足率(%)',u'當月轉銷呆帳金額(仟)',u'當年度轉銷呆帳金額(仟)'
]
df_temp.columns = col_names

df_temp.head()
# Out:
#       金融機構名稱    流通卡數    有效卡數  當月發卡數 當月停卡數 循環信用餘額(仟) 未到期分期付款餘額(仟) 當月簽帳金額(仟)  \
# 8       臺灣銀行  229685  108569   1403   773    227510         8564    591923
# 9     臺灣土地銀行  226874  123797   3130   750    273104        49967    802498
# 10  合作金庫商業銀行  434661  264265   4428  3048    632591       204449   2298644
# 11    第一商業銀行  944592  632028   9874  8862   1422132      1010711   3768957
# 12    華南商業銀行  860317  624604  11612  7488    746874      1722842   3471889
#
#    當月預借現金金額(仟) 逾期三個月以上比率(%) 逾期六個月以上比率(%) 備抵呆帳提足率(%) 當月轉銷呆帳金額(仟) 當年度轉銷呆帳金額(仟)
# 8         1125     0.361745     0.136023    500.685         501         7515
# 9          842     0.349979     0.198352     1327.9        2632        13232
# 10        3452     0.297598     0.216379    335.775        6157        34336
# 11       14321     0.169761            0    1874.76        5490        50783
# 12         996    0.0669013            0    769.897       11522        36400

# %%
df_part1 = df_temp[[u'流通卡數',u'有效卡數',u'當月發卡數',u'當月停卡數',u'循環信用餘額(仟)',
         u'未到期分期付款餘額(仟)',u'當月簽帳金額(仟)',u'當月預借現金金額(仟)',u'當年度轉銷呆帳金額(仟)']].astype('int64')
df_part2 = df_temp[[ u'逾期三個月以上比率(%)']].astype('float64')
df_temp['yyyymm'] = '201609'
df_result = pd.concat([df_temp[['yyyymm']],df_temp[u'金融機構名稱'],df_part1,df_part2],axis=1)
df_result.head(10)
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     yyyymm    金融機構名稱     流通卡數     有效卡數   當月發卡數  當月停卡數  循環信用餘額(仟)  \
# 8   201609      臺灣銀行   229685   108569    1403    773     227510
# 9   201609    臺灣土地銀行   226874   123797    3130    750     273104
# 10  201609  合作金庫商業銀行   434661   264265    4428   3048     632591
# 11  201609    第一商業銀行   944592   632028    9874   8862    1422132
# 12  201609    華南商業銀行   860317   624604   11612   7488     746874
# 13  201609    彰化商業銀行   433112   210300    2596   3545     368688
# 14  201609  上海商業儲蓄銀行   355758   177470    1428   1781     736921
# 15  201609  台北富邦商業銀行  2381409  1699013  105020  26099    6311070
# 16  201609  國泰世華商業銀行  5819486  3987545  167547  30382   14403009
# 17  201609      高雄銀行     9995     4621     119     40       7595
#
#     未到期分期付款餘額(仟)  當月簽帳金額(仟)  當月預借現金金額(仟)  當年度轉銷呆帳金額(仟)  逾期三個月以上比率(%)
# 8           8564     591923         1125          7515      0.361745
# 9          49967     802498          842         13232      0.349979
# 10        204449    2298644         3452         34336      0.297598
# 11       1010711    3768957        14321         50783      0.169761
# 12       1722842    3471889          996         36400      0.066901
# 13        163663    1202909          490         20324      0.345814
# 14        183239    1046060         7095         21170      0.872190
# 15       8321286   15414178        44722        212163      0.163105
# 16      10716675   28436766       226868        274472      0.128559
# 17           112     161677          181           915      0.219022

# %% [markdown]
# * 給予欄位正確SQL資料型態

# %%
from sqlalchemy.dialects.mssql import VARCHAR,NVARCHAR,FLOAT,INTEGER

# %%
dict_dtype={
        u'yyyymm':NVARCHAR(length=6),
        u'金融機構名稱':NVARCHAR(length=20),
        u'流通卡數':INTEGER,
        u'有效卡數':INTEGER,
        u'當月發卡數':INTEGER,
        u'當月停卡數':INTEGER,
        u'循環信用餘額(仟)':INTEGER,
        u'未到期分期付款餘額(仟)':INTEGER,
        u'當月簽帳金額(仟)':INTEGER,
        u'當月預借現金金額(仟)':INTEGER,
        u'逾期三個月以上比率(%)':FLOAT,
        u'當月轉銷呆帳金額(仟)':INTEGER
}

# %% [markdown]
# #### 連結MS資料庫
# * 寫入資料

# %%
import pyodbc 
import sqlalchemy 
connect_w = lambda x:pyodbc.connect('DRIVER={SQL Server};SERVER=dbm_public;DATABASE=External;PWD=01060728;CHARSET=utf8;',
                                     unicode_result=True)
conn_w = sqlalchemy.create_engine('mssql://',creator=connect_w).connect()

# %%
df_result.to_sql(u'測試table',conn_w,index = False, if_exists = 'replace',dtype=dict_dtype); # 若要資料要不斷累加，if_exists = 'append'

# %% [markdown]
# ## 包裝成函數

# %%
import requests
import zipfile
import pandas
import pyodbc,sqlalchemy
from sqlalchemy.dialects.mssql import VARCHAR,NVARCHAR,FLOAT,INTEGER 



def getBankCCinfo(yyymm):
    ''' 下載並解壓縮，信用卡重要業務及財務資訊揭露.zip
    參數:
        民國年月- 10509    
        
    '''
    assert isinstance(yyymm,int),'PLEASE Enter INT tyep such as 10508' # 確認輸入為整數
    url_download = 'http://www.fsc.gov.tw/fckdowndoc?file=/{}_信用卡重要資訊揭露.zip&flag=doc'.format(yyymm)
    res = requests.get(url_download)
    
    zip_dir = './data/credit_card_' + str(yyymm)
    zip_filename = './data/credit_card_' + str(yyymm) + '.zip' 
    
    ### 存檔
    with open(zip_filename,'wb') as handle:
        if not res.ok:
            print 'OOPS, something wrong!'
        else:
            for block in res.iter_content(1024):
                handle.write(block)
    
    ### 解壓縮    
    zip_ref = zipfile.ZipFile(zip_filename, 'r')
    zip_ref.extractall(zip_dir)
    zip_ref.close()

    
def parseXLSXtoSQL(yyymm):
    
    assert isinstance(yyymm,int) #確認輸入為整數
    
    zip_dir = './data/credit_card_' + str(yyymm)
    xlsx_path = zip_dir +'/'+ str(yyymm) + u'_信用卡重要資訊揭露.xlsx'
    df = pd.read_excel(xlsx_path)
    df_temp = df[8:44];
    col_names = [u'金融機構名稱',u'流通卡數',u'有效卡數',u'當月發卡數',u'當月停卡數',u'循環信用餘額(仟)',
                 u'未到期分期付款餘額(仟)',u'當月簽帳金額(仟)',u'當月預借現金金額(仟)',
                 u'逾期三個月以上比率(%)',
                 u'逾期六個月以上比率(%)',
                 u'備抵呆帳提足率(%)',u'當月轉銷呆帳金額(仟)',u'當年度轉銷呆帳金額(仟)'
    ]
    df_temp.columns = col_names
    
    df_part1 = df_temp[[u'流通卡數',u'有效卡數',u'當月發卡數',u'當月停卡數',u'循環信用餘額(仟)',
         u'未到期分期付款餘額(仟)',u'當月簽帳金額(仟)',u'當月預借現金金額(仟)',u'當年度轉銷呆帳金額(仟)']].astype('int64')
    df_part2 = df_temp[[ u'逾期三個月以上比率(%)']].astype('float64')
    
    
    yyyy = 1911 + int(str(yyymm)[:3]) # 105 --> 2016
    yyyymm = str(yyyy) + str(yyymm)[-2:]
    
    
    df_temp['yyyymm'] = yyyymm
    df_result = pd.concat([df_temp[['yyyymm']],df_temp[u'金融機構名稱'],df_part1,df_part2],axis=1)
    dict_dtype={
        u'yyyymm':NVARCHAR(length=6),
        u'金融機構名稱':NVARCHAR(length=20),
        u'流通卡數':INTEGER,
        u'有效卡數':INTEGER,
        u'當月發卡數':INTEGER,
        u'當月停卡數':INTEGER,
        u'循環信用餘額(仟)':INTEGER,
        u'未到期分期付款餘額(仟)':INTEGER,
        u'當月簽帳金額(仟)':INTEGER,
        u'當月預借現金金額(仟)':INTEGER,
        u'逾期三個月以上比率(%)':FLOAT,
        u'當月轉銷呆帳金額(仟)':INTEGER
    }
    
    df_result.to_sql(u'測試table',conn_w,index = False, if_exists = 'replace',dtype=dict_dtype)
    return df_result


if __name__ == '__main__':

    connect_w = lambda x:pyodbc.connect('DRIVER={SQL Server};SERVER=dbm_public;DATABASE=External;PWD=01060728;CHARSET=utf8;',
                                     unicode_result=True)
    conn_w = sqlalchemy.create_engine('mssql://',creator=connect_w).connect()
    
    getBankCCinfo(10508)
    parseXLSXtoSQL(10508)
    
    conn_w.close()
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda2\lib\site-packages\sqlalchemy\sql\sqltypes.py:185: SAWarning: Unicode type received non-unicode bind param value '201608'. (this warning may be suppressed after 10 occurrences)
#   (util.ellipses_string(value),))
